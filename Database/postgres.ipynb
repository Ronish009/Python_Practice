# %%
import psycopg2
print("Hello")
conn = psycopg2.connect(dbname="postgres", user="postgres", password="ronish", host="localhost", port=5432)
print(conn)
cur=conn.cursor();
cur.execute("select count(*) from pg_class")
print(cur.fetchone())
cur.execute("select * from pg_class limit 5")
print(cur.fetchmany(2))
conn.close()
# Out:
# Hello
# <connection object at 0x000001A4245D4370; dsn: 'user=postgres password=xxx dbname=postgres host=localhost port=5432', closed: 0>
# (415,)
# [(2619, 'pg_statistic', 11, 10029, 0, 10, 2, 2619, 0, 20, 410.0, 20, 2840, True, False, 'p', 'r', 31, 0, False, False, False, False, False, True, 'n', False, 0, '731', '1', '{postgres=arwdDxtm/postgres}', None, None), (1247, 'pg_type', 11, 71, 0, 10, 2, 0, 0, 15, 617.0, 15, 4171, True, False, 'p', 'r', 32, 0, False, False, False, False, False, True, 'n', False, 0, '731', '1', '{postgres=arwdDxtm/postgres,=r/postgres}', None, None)]

# %%
CREATE EXTENSION vector
# Out:
#   Cell In[9], line 1
#     CREATE EXTENSION vector
#            ^
# SyntaxError: invalid syntax
