# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

docs1 = [
    Document(page_content="when is document one. this has several sentences"),
]

splitter = RecursiveCharacterTextSplitter(
    separators=[" ",""],
    chunk_size=2,
    chunk_overlap=0,
)


chunks = splitter.split_documents(docs1)

print(chunks)

print("Fixed chunk size : ",len(chunks))

for i, c in  enumerate(chunks):
    print(f'\nchunk{i} :{c.page_content}: length  {len(c.page_content)}' )
# Out:
# [Document(metadata={}, page_content='wh'), Document(metadata={}, page_content='en'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='d'), Document(metadata={}, page_content='oc'), Document(metadata={}, page_content='um'), Document(metadata={}, page_content='en'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='ne'), Document(metadata={}, page_content='.'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='hi'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='as'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='ev'), Document(metadata={}, page_content='er'), Document(metadata={}, page_content='al'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='en'), Document(metadata={}, page_content='te'), Document(metadata={}, page_content='nc'), Document(metadata={}, page_content='es')]
# Fixed chunk size :  26
#
# chunk0 :wh: length  2
#
# chunk1 :en: length  2
#
# chunk2 :i: length  1
#
# chunk3 :s: length  1
#
# chunk4 :d: length  1
#
# chunk5 :oc: length  2
#
# chunk6 :um: length  2
#
# chunk7 :en: length  2
#
# chunk8 :t: length  1
#
# chunk9 :o: length  1
#
# chunk10 :ne: length  2
#
# chunk11 :.: length  1
#
# chunk12 :t: length  1
#
# chunk13 :hi: length  2
#
# chunk14 :s: length  1
#
# chunk15 :h: length  1
#
# chunk16 :as: length  2
#
# chunk17 :s: length  1
#
# chunk18 :ev: length  2
#
# chunk19 :er: length  2
#
# chunk20 :al: length  2
#
# chunk21 :s: length  1
#
# chunk22 :en: length  2
#
# chunk23 :te: length  2
#
# chunk24 :nc: length  2
#
# chunk25 :es: length  2
